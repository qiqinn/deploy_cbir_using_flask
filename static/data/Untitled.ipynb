# %%
import  pandas as pd

df = pd.read_csv("indexing.csv", header=None)

# %%
df.head()
# Out:
#                0            1           2    3    4          5          6   \
# 0  blimp (44).jpg  3270.166667  190.000000  0.0  0.0  31.833333  11.833333
# 1  blimp (84).jpg   150.833333    0.333333  0.0  0.0   0.000000   0.333333
# 2  blimp (24).jpg   666.333333    0.000000  0.0  0.0   0.333333   0.000000
# 3  blimp (40).jpg  1724.500000    0.666667  0.0  0.0   1.333333   0.000000
# 4  blimp (34).jpg   381.000000  748.500000  0.0  0.0   0.000000  93.666667
#
#          7    8    9   ...          89           90        91        92  \
# 0  0.333333  0.0  0.0  ...  899.281145  1202.626210  0.914816  0.825645
# 1  0.000000  0.0  0.0  ...  117.147011   180.877549  0.977867  0.955005
# 2  0.000000  0.0  0.0  ...   33.690383    38.362901  0.997529  0.989586
# 3  0.000000  0.0  0.0  ...   53.953476   145.035402  0.973512  0.964780
# 4  0.000000  0.0  0.0  ...    3.156628     3.803180  0.997099  0.989844
#
#          93        94         95         96         97         98
# ...

# %%
df[0] ='Container/' + df[0].astype(str)

# %%
df.head()
# Out:
#                          0            1           2    3    4          5   \
# 0  Container/blimp (44).jpg  3270.166667  190.000000  0.0  0.0  31.833333
# 1  Container/blimp (84).jpg   150.833333    0.333333  0.0  0.0   0.000000
# 2  Container/blimp (24).jpg   666.333333    0.000000  0.0  0.0   0.333333
# 3  Container/blimp (40).jpg  1724.500000    0.666667  0.0  0.0   1.333333
# 4  Container/blimp (34).jpg   381.000000  748.500000  0.0  0.0   0.000000
#
#           6         7    8    9   ...          89           90        91  \
# 0  11.833333  0.333333  0.0  0.0  ...  899.281145  1202.626210  0.914816
# 1   0.333333  0.000000  0.0  0.0  ...  117.147011   180.877549  0.977867
# 2   0.000000  0.000000  0.0  0.0  ...   33.690383    38.362901  0.997529
# 3   0.000000  0.000000  0.0  0.0  ...   53.953476   145.035402  0.973512
# 4  93.666667  0.000000  0.0  0.0  ...    3.156628     3.803180  0.997099
#
#          92        93        94         95         96         97         98
# ...

# %%
df.to_csv("img_index.csv", index=False)
